# %%
import hashlib
#from scipy.misc import imread, imresize, imshow
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline
import time
import numpy as np

# %% [markdown]
# # Removing Duplicate Images Using Hashing

# %%
def file_hash(filepath):
    with open(filepath, 'rb') as f:
        return md5(f.read()).hexdigest()

# %%
import os

# %%
os.getcwd()
# Out:
# "c:\\Users\\Leo's PC\\Documents\\SSTP Tests\\SSTP\\utils"

# %%
os.chdir(r"C:\Users\Leo's PC\Documents\SSTP Tests\stylegan2-ada-pytorch\trump_master")
os.getcwd()
# Out:
# "C:\\Users\\Leo's PC\\Documents\\SSTP Tests\\stylegan2-ada-pytorch\\trump_master"

# %%
file_list = os.listdir()
print(len(file_list))
# Out:
# 12325

# %%
import hashlib, os
duplicates = []
hash_keys = dict()
for index, filename in  enumerate(os.listdir('.')):  #listdir('.') = current directory
    if os.path.isfile(filename):
        with open(filename, 'rb') as f:
            filehash = hashlib.md5(f.read()).hexdigest()
        if filehash not in hash_keys: 
            hash_keys[filehash] = index
        else:
            duplicates.append((index,hash_keys[filehash]))

# %%
len(duplicates)
# Out:
# 3941

# %%
import cv2 as cv
for file_indexes in duplicates[:30]:
    try:
    
        plt.subplot(121),plt.imshow(cv.imread(file_list[file_indexes[1]]))
        plt.title(file_indexes[1]), plt.xticks([]), plt.yticks([])

        plt.subplot(122),plt.imshow(cv.imread(file_list[file_indexes[0]]))
        plt.title(str(file_indexes[0]) + ' duplicate'), plt.xticks([]), plt.yticks([])
        plt.show()
    
    except OSError as e:
        continue

# %% [markdown]
# # Delete Files After Printing

# %%
for index in duplicates:
    os.remove(file_list[index[0]])
